# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from itertools import product
warnings.filterwarnings('ignore')
sns.set(rc={'figure.figsize':(10,5)})

# %% [markdown]
# ## 1. Import the data

# %%
df = pd.read_csv('df_0216.csv')
df
# Out:
#                 id  pre_brand  cur_brand zone edu children       date  pro  \
# 0     1.000000e+12         13         12    3   1        2  8/31/2020   19
# 1     1.000000e+12         51         22    3   3        2  2/28/2021   19
# 2     1.000000e+12         11         12    1   1        3  2/28/2021   11
# 3     1.000000e+12         31         12    1   2        3  2/29/2020   12
# 4     1.000000e+12         11         12    1   2        1  8/31/2020   16
# ...            ...        ...        ...  ...  ..      ...        ...  ...
# 1902  1.000060e+12         31         98    3   1           2/28/2021   22
# 1903  1.000060e+12         33         32    2   2        1  2/28/2021   21
# 1904  1.000060e+12         11         12    1   3        1  2/28/2021   12
# 1905  1.000060e+12         12         12    1   1        1  2/28/2021   19
# 1906  1.000070e+12         11         12    1   1        3  2/28/2021   19
#
#      cur_brand2               pre_brand2  ... enroll_age age_period open_rate  \
# 0           MJN            MJN Solutions  ...        831    Stage 3       1.0
# 1        Nestle  Parent's Choice Stage 1  ...        831    Stage 3       0.0
# 2           MJN               MJN Stage1  ...        519    Stage 3       NaN
# 3           MJN            Abbott Stage1  ...        655    Stage 3       NaN
# 4           MJN               MJN Stage1  ...      -1226    Stage 0       0.0
# ...         ...                      ...  ...        ...        ...       ...
# 1902     Others            Abbott Stage1  ...        167    Stage 1       NaN
# 1903     Abbott         Abbott Solutions  ...        191    Stage 2       NaN
# 1904        MJN               MJN Stage1  ...        149    Stage 1       0.0
# 1905        MJN               MJN Stage2  ...        239    Stage 2       NaN
# 1906        MJN               MJN Stage1  ...       -240    Stage 0       NaN
#
#       ctr  or_all ctr_all  or01  ctr01  redem_rate  redem_rate1
# 0     0.5    0.63    0.06  0.68   0.04         0.8         0.75
# 1     0.0    0.09    0.03  0.10   0.07         0.0          NaN
# 2     NaN    0.00    0.00   NaN    NaN         0.0         0.00
# 3     NaN     NaN     NaN   NaN    NaN         NaN          NaN
# 4     0.0    0.04    0.00  0.25   0.00         NaN          NaN
# ...   ...     ...     ...   ...    ...         ...          ...
# 1902  NaN    0.06    0.00  0.00   0.00         1.0          NaN
# 1903  NaN    0.50    0.17   NaN    NaN         1.0          NaN
# 1904  0.0    0.47    0.03  0.67   0.00         0.2         0.25
# 1905  NaN    0.04    0.04   NaN    NaN         0.0          NaN
# 1906  NaN    0.70    0.03  0.60   0.00         0.2         0.00
#
# [1907 rows x 24 columns]

# %%
df.shape
# Out:
# (1907, 24)

# %%
df.T
# Out:
#                            0                        1                  2     \
# id              1000000000000.0          1000000000000.0    1000000000000.0
# pre_brand                    13                       51                 11
# cur_brand                    12                       22                 12
# zone                          3                        3                  1
# edu                           1                        3                  1
# children                      2                        2                  3
# date                  8/31/2020                2/28/2021          2/28/2021
# pro                          19                       19                 11
# cur_brand2                  MJN                   Nestle                MJN
# pre_brand2        MJN Solutions  Parent's Choice Stage 1         MJN Stage1
# zone2                    Others                   Others                MJN
# edu2          Elementary School              High School  Elementary School
# pro2                    Ontario                  Ontario            Alberta
# enroll_type2      Self Enrolled            Self Enrolled      Self Enrolled
# enroll_age                  831                      831                519
# age_period              Stage 3                  Stage 3            Stage 3
# open_rate                   1.0                      0.0                NaN
# ctr                         0.5                      0.0                NaN
# or_all                     0.63                     0.09                0.0
# ctr_all                    0.06                     0.03                0.0
# or01                       0.68                      0.1                NaN
# ctr01                      0.04                     0.07                NaN
# redem_rate                  0.8                      0.0                0.0
# redem_rate1                0.75                      NaN                0.0
#
#                            3                  4                  5     \
# id              1000000000000.0    1000000000000.0    1000000000000.0
# pre_brand                    31                 11                 11
# cur_brand                    12                 12                 12
# zone                          1                  1                  1
# edu                           2                  2                  2
# children                      3                  1                  1
# date                  2/29/2020          8/31/2020          8/31/2020
# pro                          12                 16                 16
# cur_brand2                  MJN                MJN                MJN
# pre_brand2        Abbott Stage1         MJN Stage1         MJN Stage1
# zone2                       MJN                MJN                MJN
# edu2          Elementary School  Elementary School  Elementary School
# pro2           British Columbia        Nova Scotia        Nova Scotia
# enroll_type2      Self Enrolled      Self Enrolled      Self Enrolled
# enroll_age                  655              -1226               -115
# age_period              Stage 3            Stage 0            Stage 0
# open_rate                   NaN                0.0                0.0
# ctr                         NaN                0.0                0.0
# or_all                      NaN               0.04               0.04
# ctr_all                     NaN                0.0                0.0
# or01                        NaN               0.25               0.25
# ctr01                       NaN                0.0                0.0
# redem_rate                  NaN                NaN                NaN
# redem_rate1                 NaN                NaN                NaN
#
#                          6                  7                  8     \
# id            1000000000000.0    1000000000000.0    1000000000000.0
# pre_brand                  11                 31                 21
# cur_brand                  12                 32                 32
# zone                        1                  1                  3
# edu                         3                  2                  1
# children                    2                  2                  2
# date               11/30/2020          8/31/2020          8/31/2020
# pro                        16                 16                 14
# cur_brand2                MJN             Abbott             Abbott
# pre_brand2         MJN Stage1      Abbott Stage1     Nestle Stage 1
# zone2                     MJN                MJN             Others
# edu2              High School  Elementary School  Elementary School
# pro2              Nova Scotia        Nova Scotia      New Brunswick
# enroll_type2    Self Enrolled      Self Enrolled      Self Enrolled
# enroll_age                337               -242                280
# age_period            Stage 2            Stage 0            Stage 2
# open_rate                 NaN                NaN                NaN
# ctr                       NaN                NaN                NaN
# or_all                   0.58                0.0                0.0
# ctr_all                  0.26                0.0                0.0
# or01                      NaN                NaN                NaN
# ctr01                     NaN                NaN                NaN
# redem_rate                0.0                NaN                1.0
# redem_rate1               NaN                NaN                NaN
#
#                            9     ...               1897               1898  \
# id              1000000000000.0  ...    1000060000000.0    1000060000000.0
# pre_brand                    31  ...                 22                 31
# cur_brand                    12  ...                 22                 32
# zone                          4  ...                  1                  2
# edu                           1  ...                  2                  2
# children                      3  ...                  1                  3
# date                 11/30/2020  ...         11/30/2020          2/28/2021
# pro                          21  ...                 19                 21
# cur_brand2                  MJN  ...             Nestle             Abbott
# pre_brand2        Abbott Stage1  ...     Nestle Stage 2      Abbott Stage1
# zone2                    Others  ...                MJN             Others
# edu2          Elementary School  ...  Elementary School  Elementary School
# pro2                     Quebec  ...            Ontario             Quebec
# enroll_type2      Self Enrolled  ...      Self Enrolled              CoReg
# enroll_age                  -90  ...                -24                141
# age_period              Stage 0  ...            Stage 0            Stage 1
# open_rate                   NaN  ...                NaN                NaN
# ctr                         NaN  ...                NaN                NaN
# or_all                      0.0  ...               0.33                0.0
# ctr_all                     0.0  ...                0.0                0.0
# or01                        0.0  ...                NaN                0.0
# ctr01                       0.0  ...                NaN                0.0
# redem_rate                  0.0  ...               0.25                0.0
# redem_rate1                 NaN  ...               0.25                0.0
#
#                            1899               1900             1901  \
# id              1000060000000.0    1000060000000.0  1000060000000.0
# pre_brand                    11                 13               31
# cur_brand                    12                 12               98
# zone                          1                  1                0
# edu                           1                  2                3
# children                      1                  1                2
# date                  2/28/2021          2/28/2021        2/28/2021
# pro                          13                 21               19
# cur_brand2                  MJN                MJN           Others
# pre_brand2           MJN Stage1      MJN Solutions    Abbott Stage1
# zone2                       MJN                MJN           Others
# edu2          Elementary School  Elementary School      High School
# pro2                   Manitoba             Quebec          Ontario
# enroll_type2              CoReg      Self Enrolled            CoReg
# enroll_age                  220                136              233
# age_period              Stage 2            Stage 1          Stage 2
# open_rate                   NaN                0.0              NaN
# ctr                         NaN                0.0              NaN
# or_all                     0.05               0.43              0.0
# ctr_all                    0.05               0.05              0.0
# or01                        NaN               0.56              NaN
# ctr01                       NaN                0.0              NaN
# redem_rate                  0.0                0.6              0.0
# redem_rate1                 NaN                0.5              NaN
#
#                            1902               1903              1904  \
# id              1000060000000.0    1000060000000.0   1000060000000.0
# pre_brand                    31                 33                11
# cur_brand                    98                 32                12
# zone                          3                  2                 1
# edu                           1                  2                 3
# children                                         1                 1
# date                  2/28/2021          2/28/2021         2/28/2021
# pro                          22                 21                12
# cur_brand2               Others             Abbott               MJN
# pre_brand2        Abbott Stage1   Abbott Solutions        MJN Stage1
# zone2                    Others             Others               MJN
# edu2          Elementary School  Elementary School       High School
# pro2               Saskatchewan             Quebec  British Columbia
# enroll_type2              CoReg      Self Enrolled     Self Enrolled
# enroll_age                  167                191               149
# age_period              Stage 1            Stage 2           Stage 1
# open_rate                   NaN                NaN               0.0
# ctr                         NaN                NaN               0.0
# or_all                     0.06                0.5              0.47
# ctr_all                     0.0               0.17              0.03
# or01                        0.0                NaN              0.67
# ctr01                       0.0                NaN               0.0
# redem_rate                  1.0                1.0               0.2
# redem_rate1                 NaN                NaN              0.25
#
#                            1905               1906
# id              1000060000000.0    1000070000000.0
# pre_brand                    12                 11
# cur_brand                    12                 12
# zone                          1                  1
# edu                           1                  1
# children                      1                  3
# date                  2/28/2021          2/28/2021
# pro                          19                 19
# cur_brand2                  MJN                MJN
# pre_brand2           MJN Stage2         MJN Stage1
# zone2                       MJN                MJN
# edu2          Elementary School  Elementary School
# pro2                    Ontario            Ontario
# enroll_type2      Self Enrolled      Self Enrolled
# enroll_age                  239               -240
# age_period              Stage 2            Stage 0
# open_rate                   NaN                NaN
# ctr                         NaN                NaN
# or_all                     0.04                0.7
# ctr_all                    0.04               0.03
# or01                        NaN                0.6
# ctr01                       NaN                0.0
# redem_rate                  0.0                0.2
# redem_rate1                 NaN                0.0
#
# [24 rows x 1907 columns]

# %% [markdown]
# ## 2. Variable Types

# %%
# let's identify the categorical variables, we will capture those of type *object*
cat_vars = [var for var in df.columns if df[var].dtype == 'O']

# number of categorical variables
len(cat_vars)
# Out:
# 11

# %%
# now let's identify the numerical variables
num_vars = [var for var in df.columns if var not in cat_vars ]

# number of numerical variables
len(num_vars)
# Out:
# 13

# %% [markdown]
# ## 3. Missing Values

# %%
# make a list of the variables that contain missing values
vars_with_na = [var for var in df.columns if df[var].isnull().sum() > 0]

# determine percentage of missing values (expressed as decimals) and display the result ordered by % of missing data
df[vars_with_na].isnull().mean().sort_values(ascending=False)
# Out:
# redem_rate1    0.785527
# open_rate      0.742003
# ctr            0.742003
# or01           0.404300
# ctr01          0.404300
# redem_rate     0.178291
# pre_brand2     0.005768
# or_all         0.004719
# ctr_all        0.004719
# dtype: float64

# %%
# for the people with email/coupon engagement "nan", it's fair to set the values with 0
df['redem_rate1'] = df['redem_rate1'].fillna(0)
df['open_rate'] = df['open_rate'].fillna(0)
df['ctr'] = df['ctr'].fillna(0)
df['or01'] = df['or01'].fillna(0)
df['ctr01'] = df['ctr01'].fillna(0)
df['redem_rate'] = df['redem_rate'].fillna(0)
df['or_all'] = df['or_all'].fillna(0)
df['ctr_all'] = df['ctr_all'].fillna(0)

# %%
# deal with outliers in "pre_brand2"
df['children'] = df['children'].replace(' ', 0)

# %%
df['children'].unique()
# Out:
# array(['2', '3', '1', 0], dtype=object)

# %%
# deal with outliers in "pre_brand2"
df['pre_brand2'] = df['pre_brand2'].replace(np.nan, "Others")

# %%
df.head()
# Out:
#              id  pre_brand  cur_brand zone edu children       date  pro  \
# 0  1.000000e+12         13         12    3   1        2  8/31/2020   19
# 1  1.000000e+12         51         22    3   3        2  2/28/2021   19
# 2  1.000000e+12         11         12    1   1        3  2/28/2021   11
# 3  1.000000e+12         31         12    1   2        3  2/29/2020   12
# 4  1.000000e+12         11         12    1   2        1  8/31/2020   16
#
#   cur_brand2               pre_brand2  ... enroll_age age_period open_rate  \
# 0        MJN            MJN Solutions  ...        831    Stage 3       1.0
# 1     Nestle  Parent's Choice Stage 1  ...        831    Stage 3       0.0
# 2        MJN               MJN Stage1  ...        519    Stage 3       0.0
# 3        MJN            Abbott Stage1  ...        655    Stage 3       0.0
# 4        MJN               MJN Stage1  ...      -1226    Stage 0       0.0
#
#    ctr  or_all ctr_all  or01  ctr01  redem_rate  redem_rate1
# 0  0.5    0.63    0.06  0.68   0.04         0.8         0.75
# 1  0.0    0.09    0.03  0.10   0.07         0.0         0.00
# 2  0.0    0.00    0.00  0.00   0.00         0.0         0.00
# 3  0.0    0.00    0.00  0.00   0.00         0.0         0.00
# 4  0.0    0.04    0.00  0.25   0.00         0.0         0.00
#
# [5 rows x 24 columns]

# %%
df.T
# Out:
#                            0                        1                  2     \
# id              1000000000000.0          1000000000000.0    1000000000000.0
# pre_brand                    13                       51                 11
# cur_brand                    12                       22                 12
# zone                          3                        3                  1
# edu                           1                        3                  1
# children                      2                        2                  3
# date                  8/31/2020                2/28/2021          2/28/2021
# pro                          19                       19                 11
# cur_brand2                  MJN                   Nestle                MJN
# pre_brand2        MJN Solutions  Parent's Choice Stage 1         MJN Stage1
# zone2                    Others                   Others                MJN
# edu2          Elementary School              High School  Elementary School
# pro2                    Ontario                  Ontario            Alberta
# enroll_type2      Self Enrolled            Self Enrolled      Self Enrolled
# enroll_age                  831                      831                519
# age_period              Stage 3                  Stage 3            Stage 3
# open_rate                   1.0                      0.0                0.0
# ctr                         0.5                      0.0                0.0
# or_all                     0.63                     0.09                0.0
# ctr_all                    0.06                     0.03                0.0
# or01                       0.68                      0.1                0.0
# ctr01                      0.04                     0.07                0.0
# redem_rate                  0.8                      0.0                0.0
# redem_rate1                0.75                      0.0                0.0
#
#                            3                  4                  5     \
# id              1000000000000.0    1000000000000.0    1000000000000.0
# pre_brand                    31                 11                 11
# cur_brand                    12                 12                 12
# zone                          1                  1                  1
# edu                           2                  2                  2
# children                      3                  1                  1
# date                  2/29/2020          8/31/2020          8/31/2020
# pro                          12                 16                 16
# cur_brand2                  MJN                MJN                MJN
# pre_brand2        Abbott Stage1         MJN Stage1         MJN Stage1
# zone2                       MJN                MJN                MJN
# edu2          Elementary School  Elementary School  Elementary School
# pro2           British Columbia        Nova Scotia        Nova Scotia
# enroll_type2      Self Enrolled      Self Enrolled      Self Enrolled
# enroll_age                  655              -1226               -115
# age_period              Stage 3            Stage 0            Stage 0
# open_rate                   0.0                0.0                0.0
# ctr                         0.0                0.0                0.0
# or_all                      0.0               0.04               0.04
# ctr_all                     0.0                0.0                0.0
# or01                        0.0               0.25               0.25
# ctr01                       0.0                0.0                0.0
# redem_rate                  0.0                0.0                0.0
# redem_rate1                 0.0                0.0                0.0
#
#                          6                  7                  8     \
# id            1000000000000.0    1000000000000.0    1000000000000.0
# pre_brand                  11                 31                 21
# cur_brand                  12                 32                 32
# zone                        1                  1                  3
# edu                         3                  2                  1
# children                    2                  2                  2
# date               11/30/2020          8/31/2020          8/31/2020
# pro                        16                 16                 14
# cur_brand2                MJN             Abbott             Abbott
# pre_brand2         MJN Stage1      Abbott Stage1     Nestle Stage 1
# zone2                     MJN                MJN             Others
# edu2              High School  Elementary School  Elementary School
# pro2              Nova Scotia        Nova Scotia      New Brunswick
# enroll_type2    Self Enrolled      Self Enrolled      Self Enrolled
# enroll_age                337               -242                280
# age_period            Stage 2            Stage 0            Stage 2
# open_rate                 0.0                0.0                0.0
# ctr                       0.0                0.0                0.0
# or_all                   0.58                0.0                0.0
# ctr_all                  0.26                0.0                0.0
# or01                      0.0                0.0                0.0
# ctr01                     0.0                0.0                0.0
# redem_rate                0.0                0.0                1.0
# redem_rate1               0.0                0.0                0.0
#
#                            9     ...               1897               1898  \
# id              1000000000000.0  ...    1000060000000.0    1000060000000.0
# pre_brand                    31  ...                 22                 31
# cur_brand                    12  ...                 22                 32
# zone                          4  ...                  1                  2
# edu                           1  ...                  2                  2
# children                      3  ...                  1                  3
# date                 11/30/2020  ...         11/30/2020          2/28/2021
# pro                          21  ...                 19                 21
# cur_brand2                  MJN  ...             Nestle             Abbott
# pre_brand2        Abbott Stage1  ...     Nestle Stage 2      Abbott Stage1
# zone2                    Others  ...                MJN             Others
# edu2          Elementary School  ...  Elementary School  Elementary School
# pro2                     Quebec  ...            Ontario             Quebec
# enroll_type2      Self Enrolled  ...      Self Enrolled              CoReg
# enroll_age                  -90  ...                -24                141
# age_period              Stage 0  ...            Stage 0            Stage 1
# open_rate                   0.0  ...                0.0                0.0
# ctr                         0.0  ...                0.0                0.0
# or_all                      0.0  ...               0.33                0.0
# ctr_all                     0.0  ...                0.0                0.0
# or01                        0.0  ...                0.0                0.0
# ctr01                       0.0  ...                0.0                0.0
# redem_rate                  0.0  ...               0.25                0.0
# redem_rate1                 0.0  ...               0.25                0.0
#
#                            1899               1900             1901  \
# id              1000060000000.0    1000060000000.0  1000060000000.0
# pre_brand                    11                 13               31
# cur_brand                    12                 12               98
# zone                          1                  1                0
# edu                           1                  2                3
# children                      1                  1                2
# date                  2/28/2021          2/28/2021        2/28/2021
# pro                          13                 21               19
# cur_brand2                  MJN                MJN           Others
# pre_brand2           MJN Stage1      MJN Solutions    Abbott Stage1
# zone2                       MJN                MJN           Others
# edu2          Elementary School  Elementary School      High School
# pro2                   Manitoba             Quebec          Ontario
# enroll_type2              CoReg      Self Enrolled            CoReg
# enroll_age                  220                136              233
# age_period              Stage 2            Stage 1          Stage 2
# open_rate                   0.0                0.0              0.0
# ctr                         0.0                0.0              0.0
# or_all                     0.05               0.43              0.0
# ctr_all                    0.05               0.05              0.0
# or01                        0.0               0.56              0.0
# ctr01                       0.0                0.0              0.0
# redem_rate                  0.0                0.6              0.0
# redem_rate1                 0.0                0.5              0.0
#
#                            1902               1903              1904  \
# id              1000060000000.0    1000060000000.0   1000060000000.0
# pre_brand                    31                 33                11
# cur_brand                    98                 32                12
# zone                          3                  2                 1
# edu                           1                  2                 3
# children                      0                  1                 1
# date                  2/28/2021          2/28/2021         2/28/2021
# pro                          22                 21                12
# cur_brand2               Others             Abbott               MJN
# pre_brand2        Abbott Stage1   Abbott Solutions        MJN Stage1
# zone2                    Others             Others               MJN
# edu2          Elementary School  Elementary School       High School
# pro2               Saskatchewan             Quebec  British Columbia
# enroll_type2              CoReg      Self Enrolled     Self Enrolled
# enroll_age                  167                191               149
# age_period              Stage 1            Stage 2           Stage 1
# open_rate                   0.0                0.0               0.0
# ctr                         0.0                0.0               0.0
# or_all                     0.06                0.5              0.47
# ctr_all                     0.0               0.17              0.03
# or01                        0.0                0.0              0.67
# ctr01                       0.0                0.0               0.0
# redem_rate                  1.0                1.0               0.2
# redem_rate1                 0.0                0.0              0.25
#
#                            1905               1906
# id              1000060000000.0    1000070000000.0
# pre_brand                    12                 11
# cur_brand                    12                 12
# zone                          1                  1
# edu                           1                  1
# children                      1                  3
# date                  2/28/2021          2/28/2021
# pro                          19                 19
# cur_brand2                  MJN                MJN
# pre_brand2           MJN Stage2         MJN Stage1
# zone2                       MJN                MJN
# edu2          Elementary School  Elementary School
# pro2                    Ontario            Ontario
# enroll_type2      Self Enrolled      Self Enrolled
# enroll_age                  239               -240
# age_period              Stage 2            Stage 0
# open_rate                   0.0                0.0
# ctr                         0.0                0.0
# or_all                     0.04                0.7
# ctr_all                    0.04               0.03
# or01                        0.0                0.6
# ctr01                       0.0                0.0
# redem_rate                  0.0                0.2
# redem_rate1                 0.0                0.0
#
# [24 rows x 1907 columns]

# %%
# make a list of the variables that contain missing values
vars_with_na = [var for var in df.columns if df[var].isnull().sum() > 0]

# determine percentage of missing values (expressed as decimals), and display the result ordered by % of missin data

df[vars_with_na].isnull().mean().sort_values(ascending=False)
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ## 4. EDA

# %%
# choose relevant columns
df1 = df[['cur_brand2', 'pre_brand2','zone2','edu2','children','pro2','enroll_type2','age_period','or01','ctr01', 'redem_rate1']]

# %%
df1.head(10)
# Out:
#   cur_brand2               pre_brand2   zone2               edu2 children  \
# 0        MJN            MJN Solutions  Others  Elementary School        2
# 1     Nestle  Parent's Choice Stage 1  Others        High School        2
# 2        MJN               MJN Stage1     MJN  Elementary School        3
# 3        MJN            Abbott Stage1     MJN  Elementary School        3
# 4        MJN               MJN Stage1     MJN  Elementary School        1
# 5        MJN               MJN Stage1     MJN  Elementary School        1
# 6        MJN               MJN Stage1     MJN        High School        2
# 7     Abbott            Abbott Stage1     MJN  Elementary School        2
# 8     Abbott           Nestle Stage 1  Others  Elementary School        2
# 9        MJN            Abbott Stage1  Others  Elementary School        3
#
#                pro2   enroll_type2 age_period  or01  ctr01  redem_rate1
# 0           Ontario  Self Enrolled    Stage 3  0.68   0.04         0.75
# 1           Ontario  Self Enrolled    Stage 3  0.10   0.07         0.00
# 2           Alberta  Self Enrolled    Stage 3  0.00   0.00         0.00
# 3  British Columbia  Self Enrolled    Stage 3  0.00   0.00         0.00
# 4       Nova Scotia  Self Enrolled    Stage 0  0.25   0.00         0.00
# 5       Nova Scotia  Self Enrolled    Stage 0  0.25   0.00         0.00
# 6       Nova Scotia  Self Enrolled    Stage 2  0.00   0.00         0.00
# 7       Nova Scotia  Self Enrolled    Stage 0  0.00   0.00         0.00
# 8     New Brunswick  Self Enrolled    Stage 2  0.00   0.00         0.00
# 9            Quebec  Self Enrolled    Stage 0  0.00   0.00         0.00

# %%
## visualization function 1
def with_hue(ax, feature, Number_of_categories, hue_categories):
    a = [p.get_height() for p in ax.patches]
    patch = [p for p in ax.patches]
    for i in range(Number_of_categories):
        total = feature.value_counts().values[i]
        for j in range(hue_categories):
            percentage = '{:.1f}%'.format(100 * a[(j*Number_of_categories + i)]/total)
            x = patch[(j*Number_of_categories + i)].get_x() + patch[(j*Number_of_categories + i)].get_width() / 2 -0.05
            y = patch[(j*Number_of_categories + i)].get_y() + patch[(j*Number_of_categories + i)].get_height() 
            ax.annotate(percentage, (x, y), size = 12)

# %%
## visualization function 2
def without_hue(ax, feature):
    total = len(feature)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), size = 12)

# %% [markdown]
# ### 4.1 Target Variables:

# %%
# plot with percentage
sns.set(rc={'figure.figsize':(14,8)})
plt.title('Current Stage 2 Brand', fontsize=17)
sns.set(rc={'figure.figsize':(12,6)})



ax = sns.countplot(x="cur_brand2", data=df1)
without_hue(ax, df1.cur_brand2)
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
df1[df1['cur_brand2'] == 'MJN'].shape
# Out:
# (805, 11)

# %%
# since we only care if the current brand is our organization, we can conduct the following manipulation:
df1['cur_brand3'] = df1['cur_brand2'].apply(lambda x: 1 if x == 'MJN' else 0)
df1
# Out:
#      cur_brand2               pre_brand2   zone2               edu2 children  \
# 0           MJN            MJN Solutions  Others  Elementary School        2
# 1        Nestle  Parent's Choice Stage 1  Others        High School        2
# 2           MJN               MJN Stage1     MJN  Elementary School        3
# 3           MJN            Abbott Stage1     MJN  Elementary School        3
# 4           MJN               MJN Stage1     MJN  Elementary School        1
# ...         ...                      ...     ...                ...      ...
# 1902     Others            Abbott Stage1  Others  Elementary School        0
# 1903     Abbott         Abbott Solutions  Others  Elementary School        1
# 1904        MJN               MJN Stage1     MJN        High School        1
# 1905        MJN               MJN Stage2     MJN  Elementary School        1
# 1906        MJN               MJN Stage1     MJN  Elementary School        3
#
#                   pro2   enroll_type2 age_period  or01  ctr01  redem_rate1  \
# 0              Ontario  Self Enrolled    Stage 3  0.68   0.04         0.75
# 1              Ontario  Self Enrolled    Stage 3  0.10   0.07         0.00
# 2              Alberta  Self Enrolled    Stage 3  0.00   0.00         0.00
# 3     British Columbia  Self Enrolled    Stage 3  0.00   0.00         0.00
# 4          Nova Scotia  Self Enrolled    Stage 0  0.25   0.00         0.00
# ...                ...            ...        ...   ...    ...          ...
# 1902      Saskatchewan          CoReg    Stage 1  0.00   0.00         0.00
# 1903            Quebec  Self Enrolled    Stage 2  0.00   0.00         0.00
# 1904  British Columbia  Self Enrolled    Stage 1  0.67   0.00         0.25
# 1905           Ontario  Self Enrolled    Stage 2  0.00   0.00         0.00
# 1906           Ontario  Self Enrolled    Stage 0  0.60   0.00         0.00
#
#       cur_brand3
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 1902           0
# 1903           0
# 1904           1
# 1905           1
# 1906           1
#
# [1907 rows x 12 columns]

# %% [markdown]
# ### 4.2 Input Variables 1: Previous Brand

# %%
df1['pre_brand2'].unique()
# Out:
# array(['MJN Solutions', "Parent's Choice Stage 1", 'MJN Stage1',
#        'Abbott Stage1', 'Nestle Stage 1', "Parent's Choice Stage 2",
#        'Abbott Solutions', 'Nestle Solutions', 'Nestle Stage 2',
#        'Abbott Stage2', 'MJN Stage2', 'Kirkland Stage 1',
#        'Abbott Specialty', "President's Choice Stage 2",
#        'Kirkland Solutions', 'Others', 'MJN Specialty'], dtype=object)

# %%
#  previous brand distribution in different segment (current brand is us VS other brands)
sns.set(rc={'figure.figsize':(16,8)})
ax = sns.countplot(x="cur_brand3", hue='pre_brand2', data=df1)
plt.title('Previous Brand', fontsize=17)

plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)
with_hue(ax,df1.cur_brand3 ,2,17)
sns.move_legend(ax, "upper left", bbox_to_anchor=(.78, 1), title='Previous Brand')

# %% [markdown]
# ### 4.3 Input Variables 2: Hospital Zone

# %%
df1['zone2'].unique()
# Out:
# array(['Others', 'MJN'], dtype=object)

# %%
# add percentage
sns.set(rc={'figure.figsize':(14,8)})
ax = sns.countplot(x="cur_brand3", hue='zone2', data=df1)
plt.title('Hospital Zone', fontsize=17)
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)

with_hue(ax,df1.cur_brand3 ,2,2)
sns.move_legend(ax, "upper left", bbox_to_anchor=(.88, 1), title='Hospital Zone')

# %% [markdown]
# ### 4.4 Input Variables 3: Province

# %%
df1['pro2'].unique()
# Out:
# array(['Ontario', 'Alberta', 'British Columbia', 'Nova Scotia',
#        'New Brunswick', 'Quebec', 'Manitoba', 'Saskatchewan',
#        'Newfoundland & Labrador', 'Northwest Territories', 'Others',
#        'Prince Edward Island', 'Yukon'], dtype=object)

# %%
len(df['pro2'].unique())
# Out:
# 13

# %%
# add percentage
ax = sns.countplot(x="cur_brand3", hue='pro2', data=df1)
plt.title('Province Distribution', fontsize=17)

plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)

with_hue(ax,df1.cur_brand3 ,2,13)
sns.move_legend(ax, "upper left", bbox_to_anchor=(.77, 1), title='Province')

# %% [markdown]
# ### 4.5 Input Variables 4: Education

# %%
df1['edu2'].unique()
# Out:
# array(['Elementary School', 'High School', 'Others'], dtype=object)

# %%
# plot with percentage
sns.set(rc={'figure.figsize':(14,8)})
ax = sns.countplot(x="cur_brand3", hue='edu2', data=df1)
plt.title('Education', fontsize=17)
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)

with_hue(ax,df1.cur_brand3 ,2,3)
sns.move_legend(ax, "upper left", bbox_to_anchor=(.8, 1), title='Education')

# %% [markdown]
# ### 4.6 Input Variables 5: Number of Children

# %%
# plot with percentage
sns.set(rc={'figure.figsize':(14,8)})
ax = sns.countplot(x="cur_brand3", hue='children', data=df1)
plt.title('Number of Children', fontsize=17)
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)
with_hue(ax,df1.cur_brand3 ,2,4)
sns.move_legend(ax, "upper left", bbox_to_anchor=(.82, 1), title='Number of Children')

# %% [markdown]
# ### 4.7 Input Variables 6: Enrollment Type

# %%
df1['enroll_type2'].unique()
# Out:
# array(['Self Enrolled', 'CoReg', 'Purchased', 'Others'], dtype=object)

# %%
# add percentage
sns.set(rc={'figure.figsize':(14,8)})
ax = sns.countplot(x="cur_brand3", hue='enroll_type2', data=df1)
plt.title('Enrollment Type', fontsize=17)
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)
with_hue(ax,df1.cur_brand3 ,2,4)
sns.move_legend(ax, "upper left", bbox_to_anchor=(.75, 1), title='Enrollment Type Education')

# %% [markdown]
# ### 4.8 Input Variables 7: Enrollment Age

# %%
df1['age_period'].unique()
# Out:
# array(['Stage 3', 'Stage 0', 'Stage 2', 'Stage 1'], dtype=object)

# %%
# add percentage
ax = sns.countplot(x="cur_brand3", hue='age_period', data=df1)
plt.title('Enrollment Age', fontsize=17)
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)
with_hue(ax,df1.cur_brand3 ,2,4)
sns.move_legend(ax, "upper left", bbox_to_anchor=(.8, 1), title='Enrollment Age Education')

# %% [markdown]
# ### 4.9 Input Variables 8: Prenatal and Newborn Email Open Rate

# %%
# plot
sns.set(rc={'figure.figsize':(8,6)})
df48 = pd.pivot_table(df1,index='cur_brand3', values='or01', aggfunc='mean')
sns.barplot(x=df48.index, y="or01", data=df48)

g = sns.barplot(x=df48.index, y="or01", data=df48)
for index, row in df48.iterrows():
    g.text(row.name,row.or01, round(row.or01,3), color='black', ha="center")
    
plt.title('"Prenatal" and "Newborn" Email Open Rate', fontsize=17)
 
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### 4.10 Input Variables 9: Stage 1 Email Click Through Rate

# %%
# plot 
df49 = pd.pivot_table(df1,index='cur_brand3', values='ctr01', aggfunc='mean')

plt.title('"Prenatal" and "Newborn" Email Click Through Rate', fontsize=15)

g = sns.barplot(x=df49.index, y="ctr01", data=df49)
for index, row in df49.iterrows():
    g.text(row.name,row.ctr01, round(row.ctr01,3), color='black', ha="center")
    
plt.title('"Prenatal" and "Newborn" Email CTR', fontsize=17)
 
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### 4.11 Input Variables 10: Stage 1 Coupon Redemption Rate

# %%
# plot 
df410 = pd.pivot_table(df1,index='cur_brand3', values='redem_rate1', aggfunc='mean')
plt.title('Stage 1 Coupon Redemption Rate', fontsize=15)
g = sns.barplot(x=df410.index, y="redem_rate1", data=df410)
for index, row in df410.iterrows():
    g.text(row.name,row.redem_rate1, round(row.redem_rate1,3), color='black', ha="center")

plt.title('Stage 1 Coupon Redemption Rate', fontsize=17)
 
plt.xlabel('Current Stage 2 Brand', fontsize=15)
plt.ylabel('Count', fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %%
df1.to_csv('df_eda_0217', index=False)
